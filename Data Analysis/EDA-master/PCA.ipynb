# %%
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

from IPython.display import Image  

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset

# %%
wine = datasets.load_wine()
x = wine.data
x.shape
# Out:
# (178, 13)

# %%
plt.scatter(x[:,0], x[:,1])
plt.show()

# %%
plt.scatter(x[:,2], x[:,3])
plt.show()

# %% [markdown]
# ## Sklearn PCA

# %%
d = 13
pca = PCA(d)
pca.fit(x)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=13, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
plt.bar(range(1,d+1), pca.explained_variance_ratio_)
plt.yscale('log')
plt.show()

# %%
xp = pca.transform(x)

# %%
plt.scatter(xp[:,0], xp[:,1])
plt.show()

# %% [markdown]
# ## PCA step-by-step

# %%
#x1 = StandardScaler().fit_transform(x)
x1 = x - np.mean(x, axis = 0)

# %%
plt.scatter(x[:,0], x[:,1])
plt.scatter(x1[:,0], x1[:,1])
plt.show()

# %%
cov = np.cov(x1.T)
cov.shape
# Out:
# (13, 13)

# %%
L, C = np.linalg.eig(cov)
print(L.shape,C.shape)
# Out:
# ((13,), (13, 13))

# %%
plt.bar(range(1,d+1), L / np.sum(L))
plt.yscale('log')
plt.show()

# %%
o = np.argsort(L)
L = L[np.flip(o)]
C = C[np.flip(o)]

# %%
plt.bar(range(1,d + 1), L)
plt.yscale('log')
plt.show()

# %%
plt.bar(range(1,d+1), L / np.sum(L))
plt.yscale('log')
plt.show()

# %%
W = C[:,:2]
W.shape
# Out:
# (13, 2)

# %%
xp = x1.dot(W)
plt.scatter(xp[:,0], xp[:,1])
plt.show()

# %%
np.sum(L)
# Out:
# 99391.50499157328

# %%
np.sum(cov)
# Out:
# 103499.28730501338
