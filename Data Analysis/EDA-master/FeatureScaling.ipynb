# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing as pre

from sklearn.datasets import fetch_california_housing

# %%
dataset = fetch_california_housing()
X_full, y_full = dataset.data, dataset.target
X = X_full[:, [0, 5]]

# %%
plt.scatter(X[:,0], X[:,1])
plt.xlim((data.min(), data.max()))
plt.ylim((data.min(), data.max()))
plt.show()

# %% [markdown]
# ## Standartization

# %%
scaler = pre.StandardScaler()
X_ = scaler.fit_transform(X)

# %%
print('mean: ', np.mean(X_, axis = 0).tolist())
print('min : ', np.min(X_, axis = 0).tolist())
print('max : ', np.max(X_, axis = 0).tolist())
print('std : ', np.std(X_, axis = 0).tolist())
# Out:
# ('mean: ', [6.609699867535816e-17, 3.4425520143415706e-18])
# ('min : ', [-1.7742994673175232, -0.22899997443511985])
# ('max : ', [5.858285811780286, 119.41910318829312])
# ('std : ', [0.9999999999999999, 1.0])

# %%
plt.scatter(X_[:,0], X_[:,1])
plt.xlim((X_.min(), X_.max()))
plt.ylim((X_.min(), X_.max()))
plt.show()

plt.scatter(X_[:,0], X_[:,1])
plt.show()

# %% [markdown]
# ## Mean normalization

# %%
X_ = pre.scale(X)

# %%
print('mean: ', np.mean(X_, axis = 0).tolist())
print('min : ', np.min(X_, axis = 0).tolist())
print('max : ', np.max(X_, axis = 0).tolist())
print('std : ', np.std(X_, axis = 0).tolist())
# Out:
# ('mean: ', [6.609699867535816e-17, 3.4425520143415706e-18])
# ('min : ', [-1.7742994673175232, -0.22899997443511985])
# ('max : ', [5.858285811780286, 119.41910318829312])
# ('std : ', [0.9999999999999999, 1.0])

# %%
plt.scatter(X_[:,0], X_[:,1])
plt.xlim((X_.min(), X_.max()))
plt.ylim((X_.min(), X_.max()))
plt.show()

plt.scatter(X_[:,0], X_[:,1])
plt.show()

# %% [markdown]
# ## MinMaxScaler

# %%
scaler = pre.MinMaxScaler()
X_ = scaler.fit_transform(X)

# %%
print('mean: ', np.mean(X_, axis = 0).tolist())
print('min : ', np.min(X_, axis = 0).tolist())
print('max : ', np.max(X_, axis = 0).tolist())
print('std : ', np.std(X_, axis = 0).tolist())
# Out:
# ('mean: ', [0.23246375932104224, 0.0019139457156597528])
# ('min : ', [0.0, 0.0])
# ('max : ', [1.0, 0.9999999999999999])
# ('std : ', [0.13101720628507704, 0.008357842486144079])

# %%
plt.scatter(X_[:,0], X_[:,1])
plt.xlim((X_.min(), X_.max()))
plt.ylim((X_.min(), X_.max()))
plt.show()

# %% [markdown]
# ## RobustScaler

# %%
scaler = pre.RobustScaler()
X_ = scaler.fit_transform(X)

# %%
print('mean: ', np.mean(X_, axis = 0).tolist())
print('min : ', np.min(X_, axis = 0).tolist())
print('max : ', np.max(X_, axis = 0).tolist())
print('std : ', np.std(X_, axis = 0).tolist())
# Out:
# ('mean: ', [0.15407986921438493, 0.29622715152461276])
# ('min : ', [-1.392251760442232, -2.4935585309601374])
# ('max : ', [5.259673830768172, 1455.1160589513665])
# ('std : ', [0.8715167073765964, 12.182471589206013])

# %%
plt.scatter(X_[:,0], X_[:,1])
plt.xlim((X_.min(), X_.max()))
plt.ylim((X_.min(), X_.max()))
plt.show()

plt.scatter(X_[:,0], X_[:,1])
plt.show()

# %% [markdown]
# ## Unit normalizer

# %%
scaler = pre.Normalizer()
X_ = scaler.fit_transform(X)

# %%
print('mean: ', np.mean(X_, axis = 0).tolist())
print('min : ', np.min(X_, axis = 0).tolist())
print('max : ', np.max(X_, axis = 0).tolist())
print('std : ', np.std(X_, axis = 0).tolist())
# Out:
# ('mean: ', [0.7478414454529068, 0.6195009371280306])
# ('min : ', [0.008224708397454279, 0.1313064012111579])
# ('max : ', [0.9913418325688542, 0.9999661765138744])
# ('std : ', [0.1627197448272118, 0.174568170076238])

# %%
plt.scatter(X_[:,0], X_[:,1])
plt.xlim((X_.min(), X_.max()))
plt.ylim((X_.min(), X_.max()))
plt.show()
